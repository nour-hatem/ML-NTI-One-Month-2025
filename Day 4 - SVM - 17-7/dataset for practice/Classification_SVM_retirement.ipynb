# %% [markdown]
# # Supervised Learning | Classification (SVM) | Case-study

# %% [markdown]
# ## Bank Customers Retirement [Classification (SVM)]

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %% [markdown]
# ### Loading & Inspecting Data

# %%
# Load the data & check what's inside
bank = pd.read_csv('data/bank_customer_retirement.csv')
bank.head()

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ### Exploring Data

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# ### Model Training & Prediction

# %% [markdown]
# ### Model Evaluation

# %% [markdown]
# ==========

# %% [markdown]
# # GOOD LUCK!
